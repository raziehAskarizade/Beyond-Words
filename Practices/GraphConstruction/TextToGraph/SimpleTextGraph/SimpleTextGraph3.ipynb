# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
import torch
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from collections import Counter
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score, classification_report
from Scripts.DataManager.GraphConstructor.DependencyGraphConstructor import DependencyGraphConstructor

stop_words = set(stopwords.words('english'))
stemmer = SnowballStemmer('english')
from Scripts.Configs.ConfigClass import Config
config = Config(r'E:\Darsi\Payan Name Arshad\Second Work\ColorIntelligence\Scripts\Configs\Config.json')
from torch_geometric.data import Data
from torch_geometric.utils import to_networkx
import networkx as nx

# %%
train_df = pd.read_csv(r'E:\Darsi\Payan Name Arshad\Second Work\ColorIntelligence\data\Amazon-Review\train_sm.csv')
test_df = pd.read_csv(r'E:\Darsi\Payan Name Arshad\Second Work\ColorIntelligence\data\Amazon-Review\test_sm.csv')

# %%
train_df.columns = ['Polarity', 'Title', 'Review']
test_df.columns = ['Polarity', 'Title', 'Review']

# %%
train_df = train_df[['Polarity', 'Review']]
test_df = test_df[['Polarity', 'Review']]

# %%
from Scripts.DataManager.GraphConstructor.DependencyGraphConstructor import DependencyGraphConstructor
graph_const = DependencyGraphConstructor(train_df['Review'][0], config)

# %%
print(graph_const.graph)
print(graph_const.node_attr)
print(graph_const.edge_index)
print(graph_const.edge_attr)
# Out:
# Data(x=[65, 300], edge_index=[2, 100], edge_attr=[100])
# tensor([[ 2.1968,  1.6901,  3.1407,  ..., 11.0030, -4.2898,  3.0589],
#         [ 6.5268,  9.8299, -4.6809,  ...,  1.6488, -7.9579,  9.5660],
#         [-3.3899, -4.7034, -0.5610,  ...,  0.7367, -0.6270,  0.0711],
#         ...,
#         [-4.9990,  2.3362, -0.5440,  ..., -0.4372, -3.0124, -0.9883],
#         [-0.2784, -1.5206, -3.2224,  ...,  2.9456, -4.7056,  3.1140],
#         [ 1.1249, -1.4770, -5.8732,  ...,  0.6504, -6.7493,  4.8398]])
# tensor([[41, 41, 49, 41, 49, 25,  4, 33, 33,  0, 28, 28, 28, 28, 33, 33, 41, 35,
#          41, 40, 40, 40, 35,  4, 40, 11,  4, 59, 11, 35, 33, 53, 36, 12, 18, 10,
#          18, 10, 33, 33, 34, 33, 33, 33, 60, 60, 60, 33, 60, 58, 60, 44, 21, 60,
#          26, 22, 22, 60,  3, 22, 60, 37, 37, 33, 37, 17, 61, 33,  0,  0, 33, 33,
#          33, 50, 50, 50, 33, 32, 50, 16, 32, 32, 45, 45, 44, 33, 33, 33, 62, 62,
#          33, 33, 19, 62, 33, 19, 33,  7, 64, 33],
#         [57, 33, 24, 49, 25,  4,  0, 47, 53, 33, 38, 63,  5, 27, 28,  5,  8, 57,
#          35, 47, 57, 48, 40, 24,  4, 58, 11, 24, 59, 42, 53, 12,  6, 36, 54, 18,
#          51, 31, 10, 42, 38, 34, 39,  8, 57, 33, 33, 60, 58,  1, 44, 21, 13,  8,
#          20, 26, 15, 22, 58,  3, 42, 38, 29, 37, 17, 53, 43, 61, 57, 14,  0,  2,
#          55, 56, 52, 33, 50, 58, 32, 30, 16, 44, 53, 23, 45,  2, 53, 33, 38,  9,
#          62, 47, 57, 19, 48, 33, 64, 46,  7, 42]])
# ['nsubj', 'aux', 'det', 'dobj', 'prep', 'pobj', 'acl', 'mark', 'nsubj', 'ccomp', 'det', 'amod', 'punct', 'compound', 'attr', 'punct', 'cc', 'nsubj', 'conj', 'mark', 'nsubj', 'aux', 'ccomp', 'det', 'dobj', 'aux', 'acl', 'det', 'npadvmod', 'punct', 'nsubj', 'prep', 'poss', 'pobj', 'compound', 'poss', 'case', 'amod', 'attr', 'punct', 'det', 'nsubj', 'acomp', 'cc', 'nsubjpass', 'aux', 'aux', 'conj', 'prep', 'pobj', 'prep', 'pobj', 'advmod', 'cc', 'poss', 'nsubj', 'advmod', 'conj', 'aux', 'xcomp', 'punct', 'det', 'compound', 'nsubj', 'prep', 'pobj', 'advmod', 'acomp', 'nsubj', 'aux', 'parataxis', 'punct', 'cc', 'mark', 'nsubj', 'aux', 'advcl', 'aux', 'xcomp', 'det', 'dobj', 'prep', 'det', 'amod', 'pobj', 'punct', 'nsubj', 'conj', 'det', 'amod', 'attr', 'nsubj', 'nsubj', 'relcl', 'aux', 'ccomp', 'acomp', 'det', 'npadvmod', 'punct']

# %%
g = to_networkx(graph_const.graph)
layout = nx.spring_layout(g)
nx.draw(g, pos=layout)
unique_words_dict = {i: graph_const.unique_words[i] for i in range(len(graph_const.unique_words))}
edge_labels_dict = {(graph_const.edge_index[0][i].item() , graph_const.edge_index[1][i].item()) : { "dep" : graph_const.edge_attr[i]} for i in range(len(graph_const.edge_attr))}
print(edge_labels_dict)
nx.set_edge_attributes(g , edge_labels_dict)
nx.draw_networkx_labels(g, pos=layout, labels=unique_words_dict)
nx.draw_networkx_edge_labels(g, pos=layout)
# Out:
# {(41, 57): {'dep': 'nsubj'}, (41, 33): {'dep': 'aux'}, (49, 24): {'dep': 'det'}, (41, 49): {'dep': 'dobj'}, (49, 25): {'dep': 'prep'}, (25, 4): {'dep': 'pobj'}, (4, 0): {'dep': 'acl'}, (33, 47): {'dep': 'nsubj'}, (33, 53): {'dep': 'nsubj'}, (0, 33): {'dep': 'ccomp'}, (28, 38): {'dep': 'det'}, (28, 63): {'dep': 'amod'}, (28, 5): {'dep': 'punct'}, (28, 27): {'dep': 'compound'}, (33, 28): {'dep': 'attr'}, (33, 5): {'dep': 'punct'}, (41, 8): {'dep': 'cc'}, (35, 57): {'dep': 'nsubj'}, (41, 35): {'dep': 'conj'}, (40, 47): {'dep': 'mark'}, (40, 57): {'dep': 'nsubj'}, (40, 48): {'dep': 'aux'}, (35, 40): {'dep': 'ccomp'}, (4, 24): {'dep': 'det'}, (40, 4): {'dep': 'dobj'}, (11, 58): {'dep': 'aux'}, (4, 11): {'dep': 'acl'}, (59, 24): {'dep': 'det'}, (11, 59): {'dep': 'npadvmod'}, (35, 42): {'dep': 'punct'}, (53, 12): {'dep': 'prep'}, (36, 6): {'dep': 'poss'}, (12, 36): {'dep': 'pobj'}, (18, 54): {'dep': 'compound'}, (10, 18): {'dep': 'poss'}, (18, 51): {'dep': 'case'}, (10, 31): {'dep': 'amod'}, (33, 10): {'dep': 'attr'}, (33, 42): {'dep': 'punct'}, (34, 38): {'dep': 'det'}, (33, 34): {'dep': 'nsubj'}, (33, 39): {'dep': 'acomp'}, (33, 8): {'dep': 'cc'}, (60, 57): {'dep': 'nsubjpass'}, (60, 33): {'dep': 'aux'}, (33, 60): {'dep': 'conj'}, (60, 58): {'dep': 'prep'}, (58, 1): {'dep': 'pobj'}, (60, 44): {'dep': 'prep'}, (44, 21): {'dep': 'pobj'}, (21, 13): {'dep': 'advmod'}, (60, 8): {'dep': 'cc'}, (26, 20): {'dep': 'poss'}, (22, 26): {'dep': 'nsubj'}, (22, 15): {'dep': 'advmod'}, (60, 22): {'dep': 'conj'}, (3, 58): {'dep': 'aux'}, (22, 3): {'dep': 'xcomp'}, (60, 42): {'dep': 'punct'}, (37, 38): {'dep': 'det'}, (37, 29): {'dep': 'compound'}, (33, 37): {'dep': 'nsubj'}, (37, 17): {'dep': 'prep'}, (17, 53): {'dep': 'pobj'}, (61, 43): {'dep': 'advmod'}, (33, 61): {'dep': 'acomp'}, (0, 57): {'dep': 'nsubj'}, (0, 14): {'dep': 'aux'}, (33, 0): {'dep': 'parataxis'}, (33, 2): {'dep': 'punct'}, (33, 55): {'dep': 'cc'}, (50, 56): {'dep': 'mark'}, (50, 52): {'dep': 'nsubj'}, (50, 33): {'dep': 'aux'}, (33, 50): {'dep': 'advcl'}, (32, 58): {'dep': 'aux'}, (50, 32): {'dep': 'xcomp'}, (16, 30): {'dep': 'det'}, (32, 16): {'dep': 'dobj'}, (32, 44): {'dep': 'prep'}, (45, 53): {'dep': 'det'}, (45, 23): {'dep': 'amod'}, (44, 45): {'dep': 'pobj'}, (33, 33): {'dep': 'conj'}, (62, 38): {'dep': 'det'}, (62, 9): {'dep': 'amod'}, (33, 62): {'dep': 'attr'}, (19, 57): {'dep': 'nsubj'}, (62, 19): {'dep': 'relcl'}, (33, 48): {'dep': 'aux'}, (19, 33): {'dep': 'ccomp'}, (33, 64): {'dep': 'acomp'}, (7, 46): {'dep': 'det'}, (64, 7): {'dep': 'npadvmod'}}
# {(0, 33): Text(0.2661327834461521, 0.023009566784679428, "{'dep': 'ccomp'}"),
#  (0, 57): Text(0.49469042866334706, -0.34552858866228886, "{'dep': 'nsubj'}"),
#  (0, 14): Text(0.6769996106089136, 0.1260095790107243, "{'dep': 'aux'}"),
#  (3, 58): Text(0.1426261180997952, -0.7369198924717624, "{'dep': 'aux'}"),
#  (4, 0): Text(0.19116810213993335, -0.16726969741658593, "{'dep': 'acl'}"),
#  (4, 24): Text(-0.39854836724796794, -0.3034579756557618, "{'dep': 'det'}"),
#  (4, 11): Text(-0.1506482132655773, -0.39918462062965443, "{'dep': 'acl'}"),
#  (7, 46): Text(-0.3805680866402126, -0.7343378375838732, "{'dep': 'det'}"),
#  (10, 18): Text(0.07982214824384276, 0.24109278809140078, "{'dep': 'poss'}"),
#  (10, 31): Text(0.28167384577415067, 0.7089616338432071, "{'dep': 'amod'}"),
#  (11, 58): Text(-0.010221146436609707, -0.6777591803437175, "{'dep': 'aux'}"),
#  (11,
#   59): Text(-0.37969429896044515, -0.38819260092174795, "{'dep': 'npadvmod'}"),
#  (12, 36): Text(-0.18629490318968311, -0.5902072357757802, "{'dep': 'pobj'}"),
#  (16, 30): Text(0.7639794468861729, -0.28402232864127064, "{'dep': 'det'}"),
#  (17, 53): Text(-0.19776048557639664, -0.3024982214788202, "{'dep': 'pobj'}"),
#  (18,
#   54): Text(-0.46498931632730645, -0.004859254370688055, "{'dep': 'compound'}"),
#  (18, 51): Text(0.4237027488354176, 0.01811300158387122, "{'dep': 'case'}"),
#  (19, 57): Text(0.3867757539755765, -0.4362126002342811, "{'dep': 'nsubj'}"),
#  (19, 33): Text(0.15821810875838158, -0.06767444478731277, "{'dep': 'ccomp'}"),
#  (21, 13): Text(-0.5785856132264418, 0.7553240723513455, "{'dep': 'advmod'}"),
#  (22, 26): Text(-0.334791862571034, -0.11650557275819877, "{'dep': 'nsubj'}"),
#  (22, 15): Text(0.42013172001245525, 0.34706394424136056, "{'dep': 'advmod'}"),
#  (22, 3): Text(0.09141148070678862, -0.32144133117642537, "{'dep': 'xcomp'}"),
#  (25, 4): Text(-0.09194899185436459, -0.2829094784380225, "{'dep': 'pobj'}"),
#  (26, 20): Text(-0.7961700108541774, -0.26557045386305905, "{'dep': 'poss'}"),
#  (28, 38): Text(-0.5365827602677145, 0.007830410924961465, "{'dep': 'det'}"),
#  (28, 63): Text(-0.5051278986686937, 0.16231089169813978, "{'dep': 'amod'}"),
#  (28, 5): Text(0.10395198171475174, -0.4604196605466455, "{'dep': 'punct'}"),
#  (28,
#   27): Text(0.22619403990150422, -0.36527107375497236, "{'dep': 'compound'}"),
#  (32, 58): Text(0.12742976485787905, -0.47999002878659086, "{'dep': 'aux'}"),
#  (32, 16): Text(0.37749891548613157, -0.19420277391672275, "{'dep': 'dobj'}"),
#  (32, 44): Text(-0.17699543512033097, 0.185310831870087, "{'dep': 'prep'}"),
#  (33, 47): Text(0.32994845729359024, 0.3895760204510491, "{'dep': 'nsubj'}"),
#  (33,
#   53): Text(-0.07329794969786897, -0.12362589802658674, "{'dep': 'nsubj'}"),
#  (33, 28): Text(-0.0655759884477429, -0.021888186098257115, "{'dep': 'attr'}"),
#  (33, 5): Text(0.21372567980631327, -0.32231121643373817, "{'dep': 'punct'}"),
#  (33, 10): Text(0.11242534572298814, 0.29578190557991907, "{'dep': 'attr'}"),
#  (33, 42): Text(-0.030806799197740434, 0.558110129007325, "{'dep': 'punct'}"),
#  (33, 34): Text(-0.36445911870131986, 0.13949583728700773, "{'dep': 'nsubj'}"),
#  (33, 39): Text(0.39436671272189155, -0.15818553001566843, "{'dep': 'acomp'}"),
#  (33, 8): Text(0.47902804720861586, -0.007693760302715166, "{'dep': 'cc'}"),
#  (33, 60): Text(0.11114489391202748, 0.07630754435308351, "{'dep': 'conj'}"),
#  (33,
#   37): Text(-0.13652484579096533, -0.07052469682985463, "{'dep': 'nsubj'}"),
#  (33, 61): Text(0.14788511333678644, 0.5074275154479633, "{'dep': 'acomp'}"),
#  (33,
#   0): Text(0.2661327834461521, 0.023009566784679428, "{'dep': 'parataxis'}"),
#  (33, 2): Text(-0.3729394464218724, 0.373733793975756, "{'dep': 'punct'}"),
#  (33, 55): Text(-0.4315896357745444, 0.22370705246836423, "{'dep': 'cc'}"),
#  (33, 50): Text(0.06723277505626266, 0.2865374723959952, "{'dep': 'advcl'}"),
#  (33, 33): Text(0.04419770964381862, 0.11622025801465025, "{'dep': 'conj'}"),
#  (33, 62): Text(0.024947526885999865, 0.1549390797659907, "{'dep': 'attr'}"),
#  (33, 48): Text(0.474391970423424, 0.13689092446865386, "{'dep': 'aux'}"),
#  (33, 64): Text(-0.19345755519375119, -0.277767802430694, "{'dep': 'acomp'}"),
#  (34, 38): Text(-0.8354658905212914, 0.1692144343102263, "{'dep': 'det'}"),
#  (35, 57): Text(0.365237704050797, -0.22115695928840146, "{'dep': 'nsubj'}"),
#  (35, 40): Text(0.3433088339749292, 0.0860641054178227, "{'dep': 'ccomp'}"),
#  (35, 42): Text(0.06167554999204294, 0.5892710671512417, "{'dep': 'punct'}"),
#  (36, 6): Text(-0.18623669353112643, -0.7020730515853945, "{'dep': 'poss'}"),
#  (37, 38): Text(-0.6075316176109369, -0.04080609980663605, "{'dep': 'det'}"),
#  (37,
#   29): Text(-0.03223080171636078, -0.4772828592029045, "{'dep': 'compound'}"),
#  (37, 17): Text(-0.26098738166949303, -0.24939702028208807, "{'dep': 'prep'}"),
#  (40, 47): Text(0.5365772324349174, 0.32825892971030496, "{'dep': 'mark'}"),
#  (40, 57): Text(0.47938413000234076, -0.31363498817306223, "{'dep': 'nsubj'}"),
#  (40, 48): Text(0.6810207455647512, 0.07557383372790971, "{'dep': 'aux'}"),
#  (40, 4): Text(0.17586180347892705, -0.13537609692735925, "{'dep': 'dobj'}"),
#  (41, 57): Text(0.38459882408461965, -0.40673141528745194, "{'dep': 'nsubj'}"),
#  (41, 33): Text(0.15604117886742472, -0.03819325984048361, "{'dep': 'aux'}"),
#  (41,
#   49): Text(-0.059261711806398054, -0.25748946700325037, "{'dep': 'dobj'}"),
#  (41, 8): Text(0.5908715164322219, -0.16210727815784903, "{'dep': 'cc'}"),
#  (41,
#   35): Text(0.24852352805720807, -0.0070323216965670066, "{'dep': 'conj'}"),
#  (44, 21): Text(-0.49590689931218584, 0.6178515227183431, "{'dep': 'pobj'}"),
#  (44, 45): Text(-0.3714725451876576, 0.4003235623286866, "{'dep': 'pobj'}"),
#  (45, 53): Text(-0.250005390073884, -0.03596963045389981, "{'dep': 'det'}"),
#  (45, 23): Text(-0.36804350169726746, 0.6188675584331464, "{'dep': 'amod'}"),
#  (49, 24): Text(-0.5388865766155719, -0.3324749186172633, "{'dep': 'det'}"),
#  (49, 25): Text(-0.2322872012219686, -0.3119264213995239, "{'dep': 'prep'}"),
#  (50, 56): Text(-0.0830466835278646, 0.6928815783026224, "{'dep': 'mark'}"),
#  (50, 52): Text(0.2972492683332906, 0.6342467044935489, "{'dep': 'nsubj'}"),
#  (50, 33): Text(0.06723277505626266, 0.2865374723959952, "{'dep': 'aux'}"),
#  (50, 32): Text(0.08500244474757418, 0.15918100951008257, "{'dep': 'xcomp'}"),
#  (53, 12): Text(-0.18821434056503863, -0.43610522697780274, "{'dep': 'prep'}"),
#  (58, 1): Text(0.19168574636489644, -0.8042731875799928, "{'dep': 'pobj'}"),
#  (59, 24): Text(-0.6275944529428357, -0.2924659559478554, "{'dep': 'det'}"),
#  (60,
#   57): Text(0.33970253912922244, -0.29223061109388476, "{'dep': 'nsubjpass'}"),
#  (60, 33): Text(0.11114489391202748, 0.07630754435308351, "{'dep': 'aux'}"),
#  (60, 58): Text(0.1766072794347764, -0.3925462795622449, "{'dep': 'prep'}"),
#  (60, 44): Text(-0.12781792054343366, 0.27275458109443296, "{'dep': 'prep'}"),
#  (60, 8): Text(0.5459752314768247, -0.0476064739642819, "{'dep': 'cc'}"),
#  (60, 22): Text(0.1253926420417698, 0.02293228173309208, "{'dep': 'conj'}"),
#  (60, 42): Text(0.03614038507046843, 0.5181974153457584, "{'dep': 'punct'}"),
#  (61, 43): Text(0.2752661704256303, 0.8958314815734386, "{'dep': 'advmod'}"),
#  (62, 38): Text(-0.44605924493397164, 0.18465767678920925, "{'dep': 'det'}"),
#  (62, 9): Text(0.40462553691621644, 0.3391008808246129, "{'dep': 'amod'}"),
#  (62,
#   19): Text(0.13896792600056282, -0.028955623035972336, "{'dep': 'relcl'}"),
#  (64,
#   7): Text(-0.4119051394144188, -0.6933233101703988, "{'dep': 'npadvmod'}")}

# %%
doc_graph.edge_index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\Darsi\Payan Name Arshad\Second Work\ColorIntelligence\Practices\GraphConstruction\TextToGraph\SimpleTextGraph\SimpleTextGraph2.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/e%3A/Darsi/Payan%20Name%20Arshad/Second%20Work/ColorIntelligence/Practices/GraphConstruction/TextToGraph/SimpleTextGraph/SimpleTextGraph2.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> doc_graph.edge_index
#
# NameError: name 'doc_graph' is not defined
