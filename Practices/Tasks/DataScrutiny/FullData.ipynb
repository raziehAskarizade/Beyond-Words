# %% [markdown]
# #### Fardin Rastakhiz @2023

# %%
import spacy
nlp = spacy.load('en_core_web_lg')
def convert_to_word(vectors):
    words = []
    print(len(vectors))
    for i in range(len(vectors)):
        print(f'{i}/{len(vectors)}')
        ms = nlp.vocab.vectors.most_similar(np.asarray([vectors[i]]), n=1)
        ws = [nlp.vocab.strings[w] for w in ms[0][0]]
        # print(ws)
        for w in ws:
            words.append(w)
        if (i+1)%20==0:
            break
    return str.join(' ', words)

# %%
# X3 = torch_geometric.data.Batch.from_data_list([dataset_list[i][0].to(device) for i in [100, 101]])

# %%
from sklearn.metrics import classification_report, f1_score, accuracy_score, precision_score, recall_score, confusion_matrix, hinge_loss

# %%
# sentence = convert_to_word(dataset_list[101][0].to('cpu').x_dict['word'])

# %%
# print(dataset_list[100][1], sentence)

# %%
for i in range(0, len(X1)):
    sent1 = convert_to_word(X1[i].x_dict['word'])
    print(f'{i}: {y1[i]}: {sent1}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\fardin\Projects\ColorIntelligence\Practices\Tasks\DataScrutiny\FullData.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/fardin/Projects/ColorIntelligence/Practices/Tasks/DataScrutiny/FullData.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> for i in range(0, len(X1)):
#       <a href='vscode-notebook-cell:/c%3A/Users/fardin/Projects/ColorIntelligence/Practices/Tasks/DataScrutiny/FullData.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a>     sent1 = convert_to_word(X1[i].x_dict['word'])
#       <a href='vscode-notebook-cell:/c%3A/Users/fardin/Projects/ColorIntelligence/Practices/Tasks/DataScrutiny/FullData.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a>     print(f'{i}: {y1[i]}: {sent1}')
#
# NameError: name 'X1' is not defined

# %%
import pandas as pd
train_text = pd.read_csv(r'C:\Users\fardin\Projects\ColorIntelligence\data\DigiKala\train.csv', header=None)
train_text.head()

# %%
train_text

# %%
import pandas as pd
import numpy as np
train_text1 = pd.read_csv(r'C:\Users\fardin\Projects\ColorIntelligence\data\DigiKala\train_sm.csv', header=None)
test_text1 = pd.read_csv(r'C:\Users\fardin\Projects\ColorIntelligence\data\DigiKala\test_sm.csv', header=None)
train_text2 = pd.read_csv(r'C:\Users\fardin\Projects\ColorIntelligence\data\DigiKala\train_sm2.csv', header=None)
test_text2 = pd.read_csv(r'C:\Users\fardin\Projects\ColorIntelligence\data\DigiKala\test_sm2.csv', header=None)
train_text = pd.concat([train_text1, test_text1, train_text2,test_text2])
train_text.index = np.arange(train_text.shape[0])
train_text.head(5)
# Out:
#    0                                                  1  \
# 0  2                     Stuning even for the non-gamer
# 1  2              The best soundtrack ever to anything.
# 2  2                                           Amazing!
# 3  2                               Excellent Soundtrack
# 4  2  Remember, Pull Your Jaw Off The Floor After He...
#
#                                                    2
# 0  This sound track was beautiful! It paints the ...
# 1  I'm reading a lot of reviews saying that this ...
# 2  This soundtrack is my favorite music of all ti...
# 3  I truly like this soundtrack and I enjoy video...
# 4  If you've played the game, you know how divine...

# %%
for i in range(train_text.shape[0]):
    # print(text)
    if "Got a replacement, and new unit works GREAT!" in (train_text[2][i]):
        print(f'aa {train_text[0][i]}: {train_text[1][i]} : {train_text[2][i]}')
# Out:
# aa 1: Worth the money! Once you get a working one! : Got a replacement, and new unit works GREAT! - Amazon won't let me change Stars, but I'd change to 4.5 if I could.!I purchased this after reading the reviews. I had no desire to use this for a party or large gathering, just one serving at a time ( 4-8 dogs). I tried it the day after it arrived and once since. The heating coils turn warm, but they don't warm up enough to prevent touching them after an hour on MAX heat. We tried two batches, after 1 hour the dogs were warm, more than room temp, but thats it. Called the company, they said to return to Amazon, we probably have a defective unit.

# %%
for i in range(train_text.shape[0]):
    # print(text)
    if "intonation in" in (train_text[2][i]):
        print(f'aa {train_text[0][i]}: {train_text[1][i]} : {train_text[2][i]}')
        break
# Out:
# aa 2: good book on stylized spoken intonation : The book contains several interesting examples of utterances which tend to be spoken with the same intonation in American English. For instance, children tease each other by singing something like "Johnny has a girlfriend" on so-so-mi-la-so-mi.Although none of the writers on stylized spoken intonation attempt to identify the musical pitches which they refer to, a reader with musical training might be able to identify those pitches. [...] and see if you agree that the four pitches of American stylized spoken intonation are do, mi, so, and la.

# %%
# import pandas as pd
# test_df = pd.read_csv(r'C:\Users\fardin\Projects\ColorIntelligence\data\DigiKala\test_sm.csv', header=None)
# train_df = pd.read_csv(r'C:\Users\fardin\Projects\ColorIntelligence\data\DigiKala\train_sm.csv', header=None)
# test_df[:5000].to_csv(r'C:\Users\fardin\Projects\ColorIntelligence\data\DigiKala\test_sm.csv', index=False)
# train_df[:50000].to_csv(r'C:\Users\fardin\Projects\ColorIntelligence\data\DigiKala\train_sm.csv', index=False)

# %%
import pandas as pd
test_df1 = pd.read_csv(r'C:\Users\fardin\Projects\ColorIntelligence\data\DigiKala\Backups\test_sm2.csv', header=None)
train_df1 = pd.read_csv(r'C:\Users\fardin\Projects\ColorIntelligence\data\DigiKala\Backups\train_sm2.csv', header=None)

test_df = pd.read_csv(r'C:\Users\fardin\Projects\ColorIntelligence\data\DigiKala\test_sm2.csv', header=None)
train_df = pd.read_csv(r'C:\Users\fardin\Projects\ColorIntelligence\data\DigiKala\train_sm2.csv', header=None)

# %%
train_df1.head(20)
# Out:
#     0                                                  1  \
# 0   2                     Stuning even for the non-gamer
# 1   1                                            Garbage
# 2   1                   Cheap! You get what you pay for!
# 3   2              Good quality, but no fraction support
# 4   1                                bad quality caliper
# 5   1                                  not very accurate
# 6   1  Do not but this Caliper!!!! zero points jumps ...
# 7   2                             cheap and accuarate!!!
# 8   2                        You get what you pay for...
# 9   2         Works well after you replace the batteries
# 10  1                    Pit Bull 6" LCD Digital Caliper
# 11  2                         Good Quality for the Price
# 12  2                A must have if your going to reload
# 13  2                     It measures stuff, better now!
# 14  2                                  Excellent product
# ...

# %%
train_df.head(20)
# Out:
#     0                                                  1  \
# 0   2                     Stuning even for the non-gamer
# 1   1                                            Garbage
# 2   1                   Cheap! You get what you pay for!
# 3   2              Good quality, but no fraction support
# 4   1                                bad quality caliper
# 5   1                                  not very accurate
# 6   1  Do not but this Caliper!!!! zero points jumps ...
# 7   2                             cheap and accuarate!!!
# 8   2                        You get what you pay for...
# 9   2         Works well after you replace the batteries
# 10  1                    Pit Bull 6" LCD Digital Caliper
# 11  2                         Good Quality for the Price
# 12  2                A must have if your going to reload
# 13  2                     It measures stuff, better now!
# 14  2                                  Excellent product
# ...

# %%
import pandas as pd

# %%
ag_train = pd.read_csv(r"data\AG\train.csv", header=None)

# %%
for i in range(ag_train.shape[0]):
    # print(text)
    if "Wacky Debut" in (ag_train[1][i] + ' ' + ag_train[2][i]):
        print(f'-> {ag_train[0][i]}: {ag_train[1][i]} : {ag_train[2][i]}')
        break
# Out:
# -> 4: Google Stock's Wacky Debut : After a false start that makes the search giant's stock appear to soar, the company's IPO on the Nasdaq settles down to a more reasonable price, just north of \$100 per share.

# %%
1: "world"
2: "Sports"
3: "Business"
4: "Sci\Tech"
# Out:
# 4
